# %% [markdown]
# Henry Pacheco Cachon
#
# Project 07
#
# Making more detailed time complexity plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hashmap = pd.read_csv("hashmap.csv")
bst = pd.read_csv("bst.csv")

# %%
hashmap.plot.scatter(x = "Total_Word_Count", y = "t")
# Out:
# <AxesSubplot:xlabel='Total_Word_Count', ylabel='t'>

# %%
bst.plot.scatter(x = "Total_Word_Count", y = "t")
# Out:
# <AxesSubplot:xlabel='Total_Word_Count', ylabel='t'>
